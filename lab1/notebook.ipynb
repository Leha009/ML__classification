# %% [markdown]
# # Классификация для определения, будет ли зарплата не менее 50.000
# ### Набор данных взят [отсюда](https://www.kaggle.com/datasets/mastmustu/income)
# Датасет изначально разделен на train (для тренировки) и test (проверки модели). Файлы называются соответственно.
#
# В данном наборе изначально дано 15 столбцов и 41.000-44.000 строк с данными для каждой фичи

# %% [markdown]
# ## Импорт библиотек
# Начало работы знаменуется импортом библиотек, которые нам понадобятся.
#
# Документации для них:
#
# [pandas](https://pandas.pydata.org/docs/)
#
# [numpy](https://numpy.org/doc/stable/)
#
# [seaborn](https://seaborn.pydata.org/)
#
# [matplotlib](https://matplotlib.org/stable/index.html)

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
import warnings

warnings.simplefilter("ignore", UserWarning)

# %%
from datetime import datetime
def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Затрачено времени: %i часов %i минут и %s секунд.' % (thour, tmin, round(tsec, 2)))

# %% [markdown]
# ## Считываем данные из файла для тренировки модели

# %%
df = pd.read_csv("../data/train.csv")

# %% [markdown]
# # Предварительная обработка данных
# ## Проверка типов данных
# Смотрим информацию о датасете, сколько записей содержится и какие типы данных у строк

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43957 entries, 0 to 43956
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              43957 non-null  int64
#  1   workclass        41459 non-null  object
#  2   fnlwgt           43957 non-null  int64
#  3   education        43957 non-null  object
#  4   educational-num  43957 non-null  int64
#  5   marital-status   43957 non-null  object
#  6   occupation       41451 non-null  object
#  7   relationship     43957 non-null  object
#  8   race             43957 non-null  object
#  9   gender           43957 non-null  object
#  10  capital-gain     43957 non-null  int64
#  11  capital-loss     43957 non-null  int64
#  12  hours-per-week   43957 non-null  int64
#  13  native-country   43194 non-null  object
#  14  income_>50K      43957 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 5.0+ MB

# %% [markdown]
# ## Убираем строки с теми данными, которые не заполнены
# Сначала посмотрим, сколько таких строк у нас всего

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2498
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2506
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      763
# income_>50K           0
# dtype: int64

# %% [markdown]
# Можно заметить, что число таких строк не большое относительно всего набора данных
# На примере workclass: 2498 на 41459 всех записей. Поэтому такими строками можно пренебречь, убрав их.
#
# Axis=0 уберет все строки (1 отвечает за столбцы), а inplace=True позволяет не порождать новый датафрейм, а изменять текущий

# %%
df.dropna(subset=["workclass", "occupation", "native-country"], axis=0, inplace=True)
df.isnull().sum() # После удаления пустых
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income_>50K        0
# dtype: int64

# %% [markdown]
# ## Дублирование строк
# Не стоит забывать и о дублях некоторых записей, их тоже надо бы убрать

# %%
df[df.duplicated()].shape # Сколько таких строк
df.drop_duplicates(inplace=True)
df.count() # Сколько строк данных осталось
# Out:
# age                40686
# workclass          40686
# fnlwgt             40686
# education          40686
# educational-num    40686
# marital-status     40686
# occupation         40686
# relationship       40686
# race               40686
# gender             40686
# capital-gain       40686
# capital-loss       40686
# hours-per-week     40686
# native-country     40686
# income_>50K        40686
# dtype: int64

# %% [markdown]
# ## Работа с нерелевантными столбцами
# ### Необходимо понять, какие столбцы не будут актуальны для нас в будущем, поэтому следует рассмотреть их поближе
# ### Начнем с типа работы

# %%
sns.countplot(y=df["workclass"])
# Out:
# <AxesSubplot: xlabel='count', ylabel='workclass'>

# %%
without_pay = [row for row in df["workclass"] if row == "Without-pay"]
print(len(without_pay))
# Out:
# 20

# %% [markdown]
# Категория Without-pay нас оприори не интересует, а количество таких записей вовсе мало - 20. Поэтому убираем эти данные из выборки

# %%
df.drop(df.index[df['workclass'] == 'Without-pay'], inplace=True)
df.shape # Смотрим, что осталось на самом деле на 20 строк меньше
# Out:
# (40666, 15)

# %% [markdown]
# ### Образование
# В данной выборке у нас есть 2 столбца, которые отвечают за образование:
#
# Один имеет текстовый формат, другой - числовой. Уберем текстовый, оставим только число

# %%
df.drop(["education"], axis=1, inplace=True) # Исключение столбца с текстовым форматом

# %% [markdown]
# ### Семейное положение
# В данной выборке также имеется 2 различных столбца для семейного положения и отношений по отдельности.
#
# Так как один из столбцов является аналогией другого, то один из них отбросим, а со вторым будет вестись работа.
#
# Было выбрано убрать столбец "relationship" (отношения), оставить "marital-status" (семейное положение)

# %%
sns.countplot(y=df["marital-status"])
# Out:
# <AxesSubplot: xlabel='count', ylabel='marital-status'>

# %% [markdown]
# Separation means that you are living apart from your spouse but are still legally married until you get a judgment of divorce.
#
# Все, что включает в себя слово married, кроме never-married, объединим в общую категорию "married". Separated, по описанию выше, тоже сюда входит.
#
# Остальное - в категорию "single"

# %%
df["marital-status"].replace(
    ["Married-civ-spouse", "Separated", "Married-spouse-absent", "Married-AF-spouse"], 
    "married", 
    inplace=True)  # Заменяем на "married"

df["marital-status"].replace(
    ["Divorced", "Never-married", "Widowed"], 
    "single", 
    inplace=True) # Заменяем на "single"

# %% [markdown]
# Посмотрим на то, что вышло по итогу: сколько людей состоят в браке, а сколько - одиноки

# %%
sns.countplot(y=df["marital-status"])
# Out:
# <AxesSubplot: xlabel='count', ylabel='marital-status'>

# %% [markdown]
# Обозначим этот столбец бинарно: 0 - одинок (-а), 1 - не одинок (-а). Это будет потом :)

# %% [markdown]
# Также вспомним, что у нас есть такой столбец как relationship, который теряет актуальность из-за разбиение на "одинок" и "в браке" в данном пункте, поэтому удаляем данный столбец

# %%
df.drop(columns='relationship', axis=1, inplace=True)

# %% [markdown]
# ### Родная страна
# Посмотрим, какие страны участвуют в выборке

# %%
sns.countplot(y=df["native-country"])
# Out:
# <AxesSubplot: xlabel='count', ylabel='native-country'>

# %% [markdown]
# Основная составляющая выборки - США. По этому можно отбросить эту фичу сразу, т.к. вклад она вносить как таковой не будет

# %%
df.drop(columns='native-country', axis=1, inplace=True)

# %% [markdown]
# # Визуализация оставшихся категориальных признаков

# %%
sns.countplot(y=df["race"])
# Out:
# <AxesSubplot: xlabel='count', ylabel='race'>

# %%
sns.countplot(y=df["occupation"]) # Род деятельности
# Out:
# <AxesSubplot: xlabel='count', ylabel='occupation'>

# %% [markdown]
# ## Замена категориальных признаков на числовые
# Заменим категории "место работы", "род деятельности", "расу", "пол" и "семейное положение" на числовые значения.

# %%
print("До замены:")
print(df.info())
freq = df["workclass"].value_counts()
i = 0
for key in freq.keys():
    df.replace(key, i, inplace=True)
    i = i + 1
    
i = 0
freq = df["occupation"].value_counts()
for key in freq.keys():
    df.replace(key, i, inplace=True)
    i = i+1
    
i = 0
freq = df["race"].value_counts()
for key in freq.keys():
    df.replace(key, i, inplace=True)
    i = i+1
    
i = 0
freq = df["gender"].value_counts()
for key in freq.keys():
    df.replace(key, i, inplace=True)
    i = i+1
    
i = 0
freq = df["marital-status"].value_counts()
for key in freq.keys():
    df.replace(key, i, inplace=True)
    i = i+1
    
print("\nПосле замены:")
print(df.info())
# Out:
# До замены:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40666 entries, 0 to 43956
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              40666 non-null  int64
#  1   workclass        40666 non-null  object
#  2   fnlwgt           40666 non-null  int64
#  3   educational-num  40666 non-null  int64
#  4   marital-status   40666 non-null  object
#  5   occupation       40666 non-null  object
#  6   race             40666 non-null  object
#  7   gender           40666 non-null  object
#  8   capital-gain     40666 non-null  int64
#  9   capital-loss     40666 non-null  int64
#  10  hours-per-week   40666 non-null  int64
#  11  income_>50K      40666 non-null  int64
# dtypes: int64(7), object(5)
# memory usage: 4.0+ MB
# None
#
# После замены:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40666 entries, 0 to 43956
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              40666 non-null  int64
#  1   workclass        40666 non-null  int64
#  2   fnlwgt           40666 non-null  int64
#  3   educational-num  40666 non-null  int64
#  4   marital-status   40666 non-null  int64
#  5   occupation       40666 non-null  int64
#  6   race             40666 non-null  int64
#  7   gender           40666 non-null  int64
#  8   capital-gain     40666 non-null  int64
#  9   capital-loss     40666 non-null  int64
#  10  hours-per-week   40666 non-null  int64
#  11  income_>50K      40666 non-null  int64
# dtypes: int64(12)
# memory usage: 4.0 MB
# None

# %% [markdown]
# # Отступление в виде наблюдений

# %% [markdown]
# Было замечено следующее при создании и проверки точностей моделей:
#
# 1. Столбец fnlwgt (финальный вес) ухудшает точность моделей в большинстве случаев
# 2. Использование SMOTE при наличии столбца fnlwgt сильно понижает точность модели, основанной на логистической прогресии, а также уменьшает точность модели К-ближайших соседей. Однако наблюдается повышение точности у других моделей
# 3. Удаление столбца fnlwgt перед SMOTE повышает точность всех моделей без исключения, особенно точность предсказания для класса 1
#
# Ниже представлено сравнение моделей, если удалять столбец fnlwgt.
#
# ![Сравнение моделей при удалении fnwght](./imgs/fnlwgt_diff.png)
#
# Можно заметить, что удаление данного столбца до SMOTE благоприятно влияет на точность моделей
#
# Также можно применить стандартизацию данных, результат ниже
#
# ![Сравнение моделей при стандартизации и без](./imgs/std_not_std_diff.png)
#
# Видно, что стандартизация данных благоприятно отражается на SVC и Наивном Байесовском классификаторах. На SVC __прирост в 21%__ в общем случае. Оно и понятно (см. описание классификатора)

# %%
df.drop(columns='fnlwgt', axis=1, inplace=True) #Повышает точность

# %% [markdown]
# # Проверка на сбалансированность данных

# %%
X = df.copy()
y = X.pop("income_>50K")

y.value_counts().plot(kind='bar', label='income_>50K')
plt.legend()
plt.title('Income_>50K');

# %% [markdown]
# Можно заметить, что у нас очень большой перевес в сторону того, что доход будет меньше 50.000. Если ничего не делать и оставить как есть, то в будущем модель будет плохо предсказывать класс 1.
#
# Таким образом нам надо бы выровнять данные... Воспользуемся SMOTE. По итогу будет осуществлен процесс генерации синтетических данных, который придет выборку к сбалансированному виду на основе класса меньшинства.

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
X, y = sm.fit_resample(X, y)

# %% [markdown]
# Посмотрим, что получилось теперь

# %%
y.value_counts().plot(kind='bar', label='income_>50K')
plt.legend()
plt.title('Income_>50K');

# %% [markdown]
# Теперь данные сбалансированны, поэтому можем приступить к обучению моделей

# %% [markdown]
# # Если захочется проверить результат с удалением fnlwgt после SMOTE

# %%
#df.drop(columns='fnlwgt', axis=1, inplace=True)

# %% [markdown]
# ## Тепловая карта
# Тепловые карты - это тип графика, который необходим для поиска зависимых переменных. Один из лучших способов найти взаимосвязь между характеристиками: тепловые карты.

# %%
plt.figure(figsize=(10,5))
c = df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                       age  workclass  educational-num  marital-status  \
# age              1.000000   0.166245         0.040624       -0.311793
# workclass        0.166245   1.000000         0.173215       -0.092461
# educational-num  0.040624   0.173215         1.000000       -0.050131
# marital-status  -0.311793  -0.092461        -0.050131        1.000000
# occupation      -0.072004  -0.052360        -0.235972        0.077347
# race            -0.033375   0.017842        -0.040176        0.040875
# gender          -0.083774  -0.042329        -0.002306        0.391672
# capital-gain     0.078802   0.055633         0.128965       -0.073232
# capital-loss     0.059374   0.033317         0.081023       -0.068956
# hours-per-week   0.101697   0.080378         0.148770       -0.218169
# income_>50K      0.237614   0.143604         0.334596       -0.410980
#
#                  occupation      race    gender  capital-gain  capital-loss  \
# age               -0.072004 -0.033375 -0.083774      0.078802      0.059374
# workclass         -0.052360  0.017842 -0.042329      0.055633      0.033317
# educational-num   -0.235972 -0.040176 -0.002306      0.128965      0.081023
# marital-status     0.077347  0.040875  0.391672     -0.073232     -0.068956
# occupation         1.000000  0.040446  0.008658     -0.057539     -0.037932
# race               0.040446  1.000000  0.065967     -0.009190     -0.019450
# gender             0.008658  0.065967  1.000000     -0.046239     -0.044283
# capital-gain      -0.057539 -0.009190 -0.046239      1.000000     -0.032177
# capital-loss      -0.037932 -0.019450 -0.044283     -0.032177      1.000000
# hours-per-week    -0.065832 -0.034901 -0.231141      0.084666      0.054923
# income_>50K       -0.165071 -0.064168 -0.215815      0.221726      0.145323
#
#                  hours-per-week  income_>50K
# age                    0.101697     0.237614
# workclass              0.080378     0.143604
# educational-num        0.148770     0.334596
# marital-status        -0.218169    -0.410980
# occupation            -0.065832    -0.165071
# race                  -0.034901    -0.064168
# gender                -0.231141    -0.215815
# capital-gain           0.084666     0.221726
# capital-loss           0.054923     0.145323
# hours-per-week         1.000000     0.227749
# income_>50K            0.227749     1.000000

# %% [markdown]
# # Построение модели
# Обучаем модель

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

feature_names = X_train.columns

from sklearn.preprocessing import StandardScaler

sc=StandardScaler()                   # хорошо отражается на SVC и наивном байесовском классификаторе
X_train_sc=sc.fit_transform(X_train)
X_test_sc=sc.transform(X_test)

# %% [markdown]
# ## Логистическая регрессия
# [Почитать тут](https://scikit-learn.ru/1-1-linear-models/#logistic-regression)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(random_state = 0, max_iter=3000)

# %% [markdown]
# ## Дерево решений
# [Статья](https://scikit-learn.ru/1-10-decision-trees/)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

# %% [markdown]
# Дерево решений показало результаты лучше

# %% [markdown]
# ## Случайный лес
# Можно в этой [статье](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) узнать.
#
# А можно на [habr](https://habr.com/ru/company/ruvds/blog/488342/)

# %%
from sklearn.ensemble import RandomForestClassifier

rt = RandomForestClassifier()

# %% [markdown]
# ## К-ближайшие соседи
# [Статья по этому классификатору](https://scikit-learn.ru/1-6-nearest-neighbors/)
#
# Принцип, лежащий в основе методов ближайшего соседа, состоит в том, чтобы найти предопределенное количество обучающих выборок, ближайших по расстоянию к новой точке, и предсказать метку по ним.

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

# %% [markdown]
# ## Машина опорных векторов (SVM)
# [Статья про SVM](https://scikit-learn.ru/1-4-support-vector-machines/#tips-on-practical-use)
#
# Для данного алгоритма нужно использовать стандартизированные/нормальные данные

# %%
from sklearn.svm import SVC

svc = SVC()

# %% [markdown]
# ## Наивный байесовский классификатор
# [Статья](https://scikit-learn.ru/1-9-naive-bayes/#bernoulli-naive-bayes)

# %%
from sklearn.naive_bayes import BernoulliNB

nb = BernoulliNB()
nb.feature_names_in_ = feature_names

# %% [markdown]
# ## Прогон всех моделей, матрица ошибок

# %%
from sklearn.metrics import classification_report, confusion_matrix

models = [logreg, dt, rt, knn, svc, nb]

for model in models:
    print(model)
    if model in [svc, nb]:
        model.fit(X_train_sc, y_train.values.ravel())
        y_pred = model.predict(X_test_sc)
    else:
        model.fit(X_train, y_train.values.ravel())
        y_pred = model.predict(X_test)
    
    print(classification_report(y_test, y_pred.round(0)))
    cf_matrix = confusion_matrix(y_pred.round(0), y_test)
    print(cf_matrix)
    
models = [logreg, dt, rt, knn, nb]
# Out:
# LogisticRegression(max_iter=3000, random_state=0)
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81     10106
#            1       0.80      0.86      0.83     10078
#
#     accuracy                           0.82     20184
#    macro avg       0.82      0.82      0.82     20184
# weighted avg       0.82      0.82      0.82     20184
#
# [[7888 1390]
#  [2218 8688]]
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84     10106
#            1       0.83      0.86      0.85     10078
#
#     accuracy                           0.84     20184
#    macro avg       0.84      0.84      0.84     20184
# weighted avg       0.84      0.84      0.84     20184
#
# [[8370 1410]
#  [1736 8668]]
# RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86     10106
#            1       0.85      0.89      0.87     10078
#
#     accuracy                           0.87     20184
#    macro avg       0.87      0.87      0.87     20184
# weighted avg       0.87      0.87      0.87     20184
#
# [[8505 1080]
#  [1601 8998]]
# KNeighborsClassifier()
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83     10106
#            1       0.80      0.90      0.85     10078
#
#     accuracy                           0.84     20184
#    macro avg       0.84      0.84      0.84     20184
# weighted avg       0.84      0.84      0.84     20184
#
# [[7835  997]
#  [2271 9081]]
# SVC()
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82     10106
#            1       0.79      0.90      0.84     10078
#
#     accuracy                           0.83     20184
#    macro avg       0.84      0.83      0.83     20184
# weighted avg       0.84      0.83      0.83     20184
#
# [[7775 1049]
#  [2331 9029]]
# BernoulliNB()
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79     10106
#            1       0.78      0.83      0.80     10078
#
#     accuracy                           0.80     20184
#    macro avg       0.80      0.80      0.80     20184
# weighted avg       0.80      0.80      0.80     20184
#
# [[7775 1752]
#  [2331 8326]]

# %% [markdown]
# Расшифровка матрицы.
#
# Имеет вид:
#
# \[\[TP TN\]
#
# \[FN FP\]\]
#
# T/F - True/False (В нашем случае доход >=50K или нет). P/N - Positive/Negative (Верно/Неверно)
#
# precision - положительная прогностическая ценность. Равна отношению TP / (TP + FP)
#
# recall - тоже смотрит отношение TP, но теперь к TP+FN
#
# f1-score - совмещает в себе обе выше перечисленные характеристики равен 2 * (Pre\*Rec)/(Pre+Rec)

# %% [markdown]
# ## ROC curve
# [Статья](https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html)
#
# Идеал - левый верхний угол, но... Возможно ли это?
#
# Чем __больше площадь__ под кривой - тем __лучше__

# %%
from sklearn.metrics import roc_curve

plt.figure(figsize=(10, 8))
for model in models:
    print(model)
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1], pos_label=1)
    lw = 2
    plt.plot(fpr, tpr, lw=lw, label='ROC curve ')
    plt.plot([0, 1], [0, 1])
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.show()
# Out:
# LogisticRegression(max_iter=3000, random_state=0)
# DecisionTreeClassifier()
# RandomForestClassifier()
# KNeighborsClassifier()
# BernoulliNB()

# %% [markdown]
# # Важность признаков по случайному лесу

# %%
importances = rt.feature_importances_
std = np.std([tree.feature_importances_ for tree in rt.estimators_], axis=0)
forest_importances = pd.Series(importances, index=feature_names)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

feature_scores = pd.Series(rt.feature_importances_, index=feature_names).sort_values(ascending=False)

feature_scores
# Out:
# marital-status     0.233004
# age                0.220231
# educational-num    0.123118
# hours-per-week     0.099725
# occupation         0.097225
# capital-gain       0.092286
# gender             0.048837
# workclass          0.037524
# capital-loss       0.030611
# race               0.017439
# dtype: float64

# %% [markdown]
# Было проведено 2 опыта: с наличием столбца fnlwgt и без него для случая, когда мы использовали SMOTE (самые лучшие результаты были именно там)
#
# Получили следующее:
#
# ![разница признаков](../useful/rt_important.png)
#
# Наличие столбца финального веса занижает важность образования, в то время как все остальные признаки находятся на тех же местах по важности (плюс минус 1 место)
#
# Можно заметить, что сам финальный вес занимает 3е место по важности, однако, как показали практические опыты, модели только хуже предсказывают данные при наличии этого признака

# %% [markdown]
# # Визуализация дерева решений
# [Отрисовка дерева написана тут](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html)

# %%
from sklearn import tree

text_representation = tree.export_text(dt,feature_names=feature_names.tolist())
print(text_representation)
# Out:
# |--- marital-status <= 0.50
# |   |--- educational-num <= 11.50
# |   |   |--- capital-gain <= 5095.50
# |   |   |   |--- educational-num <= 7.50
# |   |   |   |   |--- hours-per-week <= 42.50
# |   |   |   |   |   |--- age <= 37.50
# |   |   |   |   |   |   |--- capital-loss <= 1832.00
# |   |   |   |   |   |   |   |--- capital-gain <= 3040.00
# |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- age >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 22.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  22.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- capital-gain >  3040.00
# |   |   |   |   |   |   |   |   |--- capital-gain <= 3120.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-gain >  3120.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- capital-loss >  1832.00
# |   |   |   |   |   |   |   |--- capital-loss <= 1972.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- capital-loss >  1972.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  37.50
# |   |   |   |   |   |   |--- educational-num <= 4.50
# |   |   |   |   |   |   |   |--- occupation <= 4.50
# |   |   |   |   |   |   |   |   |--- age <= 52.50
# |   |   |   |   |   |   |   |   |   |--- race <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- race >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- race >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  52.50
# |   |   |   |   |   |   |   |   |   |--- capital-gain <= 2450.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 53.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age >  53.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- capital-gain >  2450.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- occupation >  4.50
# |   |   |   |   |   |   |   |   |--- occupation <= 7.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 39.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  39.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- age >  60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- occupation >  7.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- educational-num >  4.50
# |   |   |   |   |   |   |   |--- occupation <= 7.50
# |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 29.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 73.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  73.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  29.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- age >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |--- capital-loss <= 1757.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 53.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- age >  53.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- capital-loss >  1757.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- occupation >  7.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 1448.00
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 27.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  27.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- capital-loss >  1448.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- hours-per-week >  42.50
# |   |   |   |   |   |--- age <= 49.50
# |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |--- age <= 27.50
# |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- occupation >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 57.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  57.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  27.50
# |   |   |   |   |   |   |   |   |--- age <= 29.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- age >  29.50
# |   |   |   |   |   |   |   |   |   |--- age <= 36.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  55.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  49.50
# |   |   |   |   |   |   |--- hours-per-week <= 57.00
# |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 46.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 61.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- age >  61.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  46.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |--- age <= 53.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  53.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 44.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  44.00
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- hours-per-week >  57.00
# |   |   |   |   |   |   |   |--- hours-per-week <= 69.00
# |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 50.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  50.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- hours-per-week >  69.00
# |   |   |   |   |   |   |   |   |--- occupation <= 2.00
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- occupation >  2.00
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 72.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  72.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- educational-num >  7.50
# |   |   |   |   |--- age <= 35.50
# |   |   |   |   |   |--- age <= 26.50
# |   |   |   |   |   |   |--- age <= 23.50
# |   |   |   |   |   |   |   |--- educational-num <= 8.50
# |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 19.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  19.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- educational-num >  8.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 1803.00
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 39.00
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 31.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  31.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  39.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 20.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  20.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- capital-loss >  1803.00
# |   |   |   |   |   |   |   |   |   |--- occupation <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss <= 2468.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss >  2468.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- occupation >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  23.50
# |   |   |   |   |   |   |   |--- hours-per-week <= 43.50
# |   |   |   |   |   |   |   |   |--- capital-gain <= 2994.00
# |   |   |   |   |   |   |   |   |   |--- capital-loss <= 1881.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- capital-loss >  1881.50
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss <= 2014.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss >  2014.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- capital-gain >  2994.00
# |   |   |   |   |   |   |   |   |   |--- capital-gain <= 3120.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- capital-gain >  3120.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- age >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- hours-per-week >  43.50
# |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 44.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  44.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- educational-num >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age >  24.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 47.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  47.00
# |   |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- age >  26.50
# |   |   |   |   |   |   |--- capital-loss <= 1794.00
# |   |   |   |   |   |   |   |--- occupation <= 4.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 40.50
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- educational-num >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss <= 1532.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss >  1532.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- hours-per-week >  40.50
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 26
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 43.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  43.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- occupation >  4.50
# |   |   |   |   |   |   |   |   |--- occupation <= 9.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 72.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  72.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- occupation >  9.50
# |   |   |   |   |   |   |   |   |   |--- workclass <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- workclass >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- capital-loss >  1794.00
# |   |   |   |   |   |   |   |--- capital-loss <= 1978.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 1938.00
# |   |   |   |   |   |   |   |   |   |--- workclass <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- workclass >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-loss >  1938.00
# |   |   |   |   |   |   |   |   |   |--- occupation <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- occupation >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- capital-loss >  1978.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 2396.00
# |   |   |   |   |   |   |   |   |   |--- age <= 27.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  27.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- capital-loss >  2396.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  35.50
# |   |   |   |   |   |--- hours-per-week <= 34.50
# |   |   |   |   |   |   |--- educational-num <= 9.50
# |   |   |   |   |   |   |   |--- capital-loss <= 912.50
# |   |   |   |   |   |   |   |   |--- age <= 63.50
# |   |   |   |   |   |   |   |   |   |--- age <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- age >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- race >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  63.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- capital-loss >  912.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 2009.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-loss >  2009.50
# |   |   |   |   |   |   |   |   |   |--- age <= 77.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  77.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- educational-num >  9.50
# |   |   |   |   |   |   |   |--- hours-per-week <= 24.50
# |   |   |   |   |   |   |   |   |--- age <= 60.50
# |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  60.50
# |   |   |   |   |   |   |   |   |   |--- age <= 65.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  65.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- hours-per-week >  24.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 742.50
# |   |   |   |   |   |   |   |   |   |--- capital-gain <= 1551.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- capital-gain >  1551.50
# |   |   |   |   |   |   |   |   |   |   |--- capital-gain <= 4058.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- capital-gain >  4058.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- capital-loss >  742.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- hours-per-week >  34.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- capital-loss <= 1769.50
# |   |   |   |   |   |   |   |   |--- occupation <= 4.50
# |   |   |   |   |   |   |   |   |   |--- capital-loss <= 1529.00
# |   |   |   |   |   |   |   |   |   |   |--- capital-gain <= 4973.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 32
# |   |   |   |   |   |   |   |   |   |   |--- capital-gain >  4973.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- capital-loss >  1529.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- occupation >  4.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 25
# |   |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- occupation >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- capital-loss >  1769.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 1978.50
# |   |   |   |   |   |   |   |   |   |--- age <= 66.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- age >  66.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-loss >  1978.50
# |   |   |   |   |   |   |   |   |   |--- capital-loss <= 2161.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- capital-loss >  2161.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- occupation <= 3.50
# |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 52.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- age >  43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  52.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 41.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  37.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  41.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- race >  2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- occupation >  3.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 1794.00
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- educational-num >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age >  43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- capital-loss >  1794.00
# |   |   |   |   |   |   |   |   |   |--- occupation <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- occupation >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- capital-gain >  5095.50
# |   |   |   |--- age <= 60.50
# |   |   |   |   |--- educational-num <= 2.00
# |   |   |   |   |   |--- capital-gain <= 27827.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- capital-gain >  27827.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- educational-num >  2.00
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- capital-gain <= 6897.50
# |   |   |   |   |   |   |   |--- capital-gain <= 5449.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- capital-gain >  5449.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- capital-gain >  6897.50
# |   |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |   |--- age <= 33.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  33.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- occupation >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- age >  60.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- occupation <= 10.50
# |   |   |   |   |   |   |--- hours-per-week <= 59.50
# |   |   |   |   |   |   |   |--- capital-gain <= 10585.50
# |   |   |   |   |   |   |   |   |--- capital-gain <= 9976.00
# |   |   |   |   |   |   |   |   |   |--- age <= 66.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  66.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- age >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-gain >  9976.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- capital-gain >  10585.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- hours-per-week >  59.50
# |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- occupation >  10.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- occupation <= 4.00
# |   |   |   |   |   |   |--- capital-gain <= 15308.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- capital-gain >  15308.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- occupation >  4.00
# |   |   |   |   |   |   |--- class: 0
# |   |--- educational-num >  11.50
# |   |   |--- capital-gain <= 5095.50
# |   |   |   |--- occupation <= 4.50
# |   |   |   |   |--- capital-loss <= 1782.50
# |   |   |   |   |   |--- capital-loss <= 1497.50
# |   |   |   |   |   |   |--- capital-gain <= 4973.50
# |   |   |   |   |   |   |   |--- age <= 27.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 43.50
# |   |   |   |   |   |   |   |   |   |--- age <= 23.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  23.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- age >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- hours-per-week >  43.50
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- age >  27.50
# |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 30.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  30.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 29
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |--- occupation >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- capital-gain >  4973.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- capital-loss >  1497.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- capital-loss >  1782.50
# |   |   |   |   |   |--- capital-loss <= 1989.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- capital-loss <= 1881.50
# |   |   |   |   |   |   |   |   |--- educational-num <= 12.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- educational-num >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- capital-loss >  1881.50
# |   |   |   |   |   |   |   |   |--- age <= 28.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- occupation >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  28.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- capital-loss >  1989.50
# |   |   |   |   |   |   |--- capital-loss <= 2115.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- capital-loss >  2115.50
# |   |   |   |   |   |   |   |--- occupation <= 0.50
# |   |   |   |   |   |   |   |   |--- age <= 49.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  49.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- occupation >  0.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 2205.00
# |   |   |   |   |   |   |   |   |   |--- workclass <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- workclass >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- capital-loss >  2205.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- occupation >  4.50
# |   |   |   |   |--- occupation <= 9.50
# |   |   |   |   |   |--- capital-loss <= 1803.00
# |   |   |   |   |   |   |--- occupation <= 5.50
# |   |   |   |   |   |   |   |--- hours-per-week <= 53.00
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 7.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- hours-per-week >  7.50
# |   |   |   |   |   |   |   |   |   |--- age <= 60.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- age >  60.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 34.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  34.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- hours-per-week >  53.00
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 65.00
# |   |   |   |   |   |   |   |   |   |--- age <= 42.00
# |   |   |   |   |   |   |   |   |   |   |--- age <= 38.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- age >  38.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  42.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- hours-per-week >  65.00
# |   |   |   |   |   |   |   |   |   |--- age <= 33.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  33.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- occupation >  5.50
# |   |   |   |   |   |   |   |--- age <= 38.50
# |   |   |   |   |   |   |   |   |--- workclass <= 1.50
# |   |   |   |   |   |   |   |   |   |--- age <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  63.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- age >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- workclass >  1.50
# |   |   |   |   |   |   |   |   |   |--- capital-loss <= 859.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- capital-loss >  859.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  38.50
# |   |   |   |   |   |   |   |   |--- age <= 61.50
# |   |   |   |   |   |   |   |   |   |--- race <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- race >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- age >  61.50
# |   |   |   |   |   |   |   |   |   |--- workclass <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- workclass >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- capital-loss >  1803.00
# |   |   |   |   |   |   |--- capital-loss <= 2177.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- capital-loss >  2177.00
# |   |   |   |   |   |   |   |--- occupation <= 8.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- occupation >  8.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- occupation >  9.50
# |   |   |   |   |   |--- age <= 36.50
# |   |   |   |   |   |   |--- educational-num <= 13.50
# |   |   |   |   |   |   |   |--- age <= 24.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  24.50
# |   |   |   |   |   |   |   |   |--- capital-loss <= 1952.00
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- educational-num >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss <= 943.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- capital-loss >  943.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-loss >  1952.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- educational-num >  13.50
# |   |   |   |   |   |   |   |--- capital-loss <= 951.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- capital-loss >  951.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |--- age <= 58.50
# |   |   |   |   |   |   |   |--- age <= 47.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 43.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 42.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  42.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  43.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 83.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  83.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 42.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 39.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age >  39.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  42.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  47.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 49.00
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 30.00
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  30.00
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- hours-per-week >  49.00
# |   |   |   |   |   |   |   |   |   |--- age <= 48.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- age >  48.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  58.50
# |   |   |   |   |   |   |   |--- hours-per-week <= 39.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- hours-per-week >  39.00
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 74.50
# |   |   |   |   |   |   |   |   |   |--- workclass <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  60.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- workclass >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- hours-per-week >  74.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- capital-gain >  5095.50
# |   |   |   |--- capital-gain <= 7073.50
# |   |   |   |   |--- capital-gain <= 6681.50
# |   |   |   |   |   |--- capital-gain <= 6457.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- capital-gain >  6457.50
# |   |   |   |   |   |   |--- age <= 54.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  54.00
# ...
# |   |   |   |   |   |   |   |   |   |--- occupation <= 6.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- occupation >  6.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- hours-per-week >  53.50
# |   |   |   |   |   |   |--- age <= 25.50
# |   |   |   |   |   |   |   |--- occupation <= 8.50
# |   |   |   |   |   |   |   |   |--- occupation <= 1.50
# |   |   |   |   |   |   |   |   |   |--- age <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- age >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- occupation >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- occupation >  8.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 57.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- hours-per-week >  57.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- age >  25.50
# |   |   |   |   |   |   |   |--- workclass <= 1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- occupation >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 14.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- educational-num >  14.00
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- workclass >  1.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 62.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- hours-per-week >  62.50
# |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 67.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- hours-per-week >  67.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- age >  28.50
# |   |   |   |   |   |--- hours-per-week <= 44.50
# |   |   |   |   |   |   |--- hours-per-week <= 37.50
# |   |   |   |   |   |   |   |--- age <= 40.50
# |   |   |   |   |   |   |   |   |--- age <= 35.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  35.50
# |   |   |   |   |   |   |   |   |   |--- age <= 36.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  33.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- age >  36.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- age >  40.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 31.00
# |   |   |   |   |   |   |   |   |   |--- workclass <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- race <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- race >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- workclass >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- hours-per-week >  31.00
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- educational-num >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- hours-per-week >  37.50
# |   |   |   |   |   |   |   |--- age <= 41.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- educational-num >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- educational-num >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- age >  41.50
# |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- occupation <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- occupation >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- occupation >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |--- age <= 46.50
# |   |   |   |   |   |   |   |   |   |   |--- educational-num <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- educational-num >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- age >  46.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 54.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- age >  54.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |--- hours-per-week >  44.50
# |   |   |   |   |   |   |--- occupation <= 1.50
# |   |   |   |   |   |   |   |--- occupation <= 0.50
# |   |   |   |   |   |   |   |   |--- hours-per-week <= 77.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- hours-per-week >  77.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- occupation >  0.50
# |   |   |   |   |   |   |   |   |--- age <= 40.50
# |   |   |   |   |   |   |   |   |   |--- capital-gain <= 1087.00
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  56.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- capital-gain >  1087.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- age >  40.50
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 48.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- age >  48.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- occupation >  1.50
# |   |   |   |   |   |   |   |--- hours-per-week <= 48.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- occupation <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- occupation >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- educational-num <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- educational-num >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 50.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- age >  50.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- hours-per-week >  48.50
# |   |   |   |   |   |   |   |   |--- educational-num <= 14.50
# |   |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week <= 64.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- hours-per-week >  64.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- age <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- age >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |--- educational-num >  14.50
# |   |   |   |   |   |   |   |   |   |--- age <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- workclass <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- workclass >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- age >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- capital-gain <= 543.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- capital-gain >  543.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- capital-loss >  2217.50
# |   |   |   |--- capital-loss <= 2365.50
# |   |   |   |   |--- capital-loss <= 2310.50
# |   |   |   |   |   |--- hours-per-week <= 46.50
# |   |   |   |   |   |   |--- age <= 43.50
# |   |   |   |   |   |   |   |--- occupation <= 1.00
# |   |   |   |   |   |   |   |   |--- educational-num <= 8.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- educational-num >  8.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- occupation >  1.00
# |   |   |   |   |   |   |   |   |--- capital-loss <= 2234.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- capital-loss >  2234.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  43.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- hours-per-week >  46.50
# |   |   |   |   |   |   |--- age <= 46.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  46.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- capital-loss >  2310.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- capital-loss >  2365.50
# |   |   |   |   |--- capital-loss <= 3726.50
# |   |   |   |   |   |--- educational-num <= 5.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- educational-num >  5.00
# |   |   |   |   |   |   |--- hours-per-week <= 30.00
# |   |   |   |   |   |   |   |--- hours-per-week <= 22.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- hours-per-week >  22.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- hours-per-week >  30.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- capital-loss >  3726.50
# |   |   |   |   |   |--- class: 0
# |   |--- capital-gain >  4668.50
# |   |   |--- capital-gain <= 7055.50
# |   |   |   |--- capital-gain <= 4826.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- capital-gain >  4826.00
# |   |   |   |   |--- occupation <= 1.50
# |   |   |   |   |   |--- capital-gain <= 5194.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- capital-gain >  5194.50
# |   |   |   |   |   |   |--- age <= 64.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  64.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- occupation >  1.50
# |   |   |   |   |   |--- hours-per-week <= 55.00
# |   |   |   |   |   |   |--- age <= 59.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- age >  59.50
# |   |   |   |   |   |   |   |--- age <= 62.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- age >  62.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- hours-per-week >  55.00
# |   |   |   |   |   |   |--- educational-num <= 12.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- educational-num >  12.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- capital-gain >  7055.50
# |   |   |   |--- capital-gain <= 8296.00
# |   |   |   |   |--- capital-gain <= 7436.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- capital-gain >  7436.50
# |   |   |   |   |   |--- educational-num <= 12.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- educational-num >  12.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- capital-gain >  8296.00
# |   |   |   |   |--- age <= 20.00
# |   |   |   |   |   |--- educational-num <= 8.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- educational-num >  8.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- age >  20.00
# |   |   |   |   |   |--- class: 1

# %%
plt.figure(figsize=(15, 8))
tree.plot_tree(dt,
               max_depth = 2,
               feature_names = feature_names.tolist(), 
               filled = True);
plt.show()

# %% [markdown]
# Показатель gini больше нуля означает, что образцы, содержащиеся в этом узле, принадлежат к разным классам.
#
# Если не указывать max_depth, то получится вот такое
#
# ![дерево решений все](./imgs/dt.png)

# %% [markdown]
# # GridSearch
# Найдем лучшие параметры для классификаторов, а затем посмотрим результат
#
# __Случайный лес__

# %%
from sklearn.model_selection import GridSearchCV

params_rfc = { 
    'random_state' : [0, 10, 100, 250, None],
    'n_estimators': [10, 50, 100, 250],  # Сколько деревьев
    'max_depth' : [5, 10, 50, None],      # Макс. глубина
    'max_features' : ["sqrt", "log2", 4] # Количество функций, которые следует учитывать при поиске лучшего разделения
}

rt=RandomForestClassifier()
random_search = GridSearchCV(estimator=rt, param_grid=params_rfc, cv=2, n_jobs=-1)
start_time = timer(None)
random_search.fit(X_train, y_train.values.ravel())
timer(start_time)
print(random_search.best_params_)
print(random_search.best_score_)
rf_bp = random_search.best_params_
# Out:
#  Затрачено времени: 0 часов 2 минут и 31.65 секунд.
# {'max_depth': 50, 'max_features': 4, 'n_estimators': 250, 'random_state': 0}
# 0.8544828932597979

# %% [markdown]
# ### Логистическая регрессия

# %%
params_rfc = { 
    'max_iter' : [10, 100, 1000, 3000],
    'random_state' : [0, 10, 100, 250, None],
}

logreg = LogisticRegression()
random_search = GridSearchCV(estimator=logreg, param_grid=params_rfc, cv=2, n_jobs=-1)
start_time = timer(None)
random_search.fit(X_train, y_train.values.ravel())
timer(start_time)
print(random_search.best_params_)
print(random_search.best_score_)
rf_bp = random_search.best_params_

# %% [markdown]
# ### Дерево решений

# %%
params_rfc = { 
    'max_depth' : [5, 10, 50, None],      # Макс. глубина
    'random_state' : [0, 10, 100, 250, None],
    'splitter': ["best", "random"],
}

dt = DecisionTreeClassifier()
random_search = GridSearchCV(estimator=dt, param_grid=params_rfc, cv=2, n_jobs=-1)
start_time = timer(None)
random_search.fit(X_train, y_train.values.ravel())
timer(start_time)
print(random_search.best_params_)
print(random_search.best_score_)
rf_bp = random_search.best_params_

# %% [markdown]
# ### К-ближайшие соседи
# Веса:
#
# ‘uniform’ : uniform weights. All points in each neighborhood are weighted equally.
#
# ‘distance’ : weight points by the inverse of their distance. in this case, closer neighbors of a query point will have a greater influence than neighbors which are further away.

# %%
params_rfc = { 
    'n_neighbors' : [2, 5, 10, 15],
    'weights': ['uniform', 'distance'],
}

knn = KNeighborsClassifier()
random_search = GridSearchCV(estimator=knn, param_grid=params_rfc, cv=2, n_jobs=-1)
start_time = timer(None)
random_search.fit(X_train, y_train.values.ravel())
timer(start_time)
print(random_search.best_params_)
print(random_search.best_score_)
rf_bp = random_search.best_params_

# %% [markdown]
# ## Прогон после GridSearch

# %%
logreg = LogisticRegression(random_state = 0, max_iter=3000)
dt = DecisionTreeClassifier(max_depth=10, random_state=100)
rt = RandomForestClassifier(max_features=4, n_estimators=250)
knn = KNeighborsClassifier(n_neighbors=10, weights='distance')

models = [logreg, dt, rt, knn]

for model in models:
    print(model)
    if model in [svc, nb]:
        model.fit(X_train_sc, y_train.values.ravel())
        y_pred = model.predict(X_test_sc)
    else:
        model.fit(X_train, y_train.values.ravel())
        y_pred = model.predict(X_test)
    
    print(classification_report(y_test, y_pred.round(0)))
    cf_matrix = confusion_matrix(y_pred.round(0), y_test)
    print(cf_matrix)
    
models = [logreg, dt, rt, knn]

# %%
plt.figure(figsize=(10, 8))
for model in models:
    print(model)
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1], pos_label=1)
    lw = 2
    plt.plot(fpr, tpr, lw=lw, label='ROC curve ')
    plt.plot([0, 1], [0, 1])
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.show()
